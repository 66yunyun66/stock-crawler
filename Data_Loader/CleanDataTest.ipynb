# %%
import pandas as pd

# %%
df = pd.read_csv("data.csv",encoding="utf-8",sep=",")

# %%
df.head()
# Out:
#    序号      代码    名称    最新价     涨跌幅    涨跌额       成交量          成交额     振幅  \
# 0   1  603120   N肯特  48.90  226.00  33.90  178495.0  922715936.0  77.33
# 1   2  301232  飞沃科技  28.24   20.02   4.71  117734.0  326164976.8  10.16
# 2   3  300605  恒锋信息  15.48   20.00   2.58  229878.0  342895284.5  21.40
# 3   4  300941  创识科技  24.18   20.00   4.03  203414.0  460898416.1  24.62
# 4   5  301618  长联科技  84.14   19.99  14.02   31468.0  250445232.0  18.51
#
#       最高  ...    量比    换手率  市盈率-动态   市净率           总市值          流通市值    涨速  \
# 0  60.06  ...   NaN  80.61   47.28  3.92  4.420560e+09  1.082833e+09  0.04
# 1  28.24  ...  9.40  26.36  -21.90  1.46  2.122585e+09  1.261404e+09  0.00
# 2  15.48  ...  3.16  19.33  -77.61  4.82  2.547634e+09  1.840949e+09  0.00
# 3  24.18  ...  3.68  16.77  131.21  3.92  4.950855e+09  2.932562e+09  0.00
# 4  84.14  ...  4.22  19.53   72.48  5.88  5.421973e+09  1.355495e+09  0.00
#
#    5分钟涨跌  60日涨跌幅  年初至今涨跌幅
# 0  -0.06  226.00   226.00
# 1   1.66   20.74    14.33
# ...

# %%
required_columns = ['代码', '名称', '最新价', '涨跌幅']
if not set(required_columns).issubset(df.columns): 
    raise ValueError("关键字段缺失")

# %%
valid_data = df[~(df['涨跌幅'] >= -10) & (df['涨跌幅'] <= 10)]
valid_data.head()
# Out:
#         序号      代码    名称    最新价    涨跌幅   涨跌额       成交量           成交额    振幅  \
# 5387  5388  603709  中源家居  13.12 -10.01 -1.46  125940.0  1.652382e+08  1.17
# 5388  5389  300153  科泰电源  31.39 -10.01 -3.49  430270.0  1.386323e+09  8.89
# 5389  5390    2923  润都股份  12.95 -10.01 -1.44  407543.0  5.442203e+08  8.34
# 5390  5391  300657  弘信电子  26.16 -10.38 -3.03  704689.0  1.859348e+09  7.16
# 5391  5392  301256  华融化学  13.12 -12.24 -1.83  475890.0  6.570293e+08  8.90
#
#          最高  ...    量比    换手率  市盈率-动态    市净率           总市值          流通市值  \
# 5387  13.29  ...  1.94  10.09  498.89   2.89  1.651839e+09  1.637376e+09
# 5388  34.30  ...  0.98  13.52  300.93  11.69  1.004480e+10  9.992382e+09
# 5389  14.15  ...  0.85  15.79   87.48   3.77  4.336868e+09  3.342199e+09
# 5390  27.55  ...  1.60  15.43  469.64   9.85  1.277550e+10  1.194477e+10
# 5391  14.34  ...  0.79   9.91   62.66   3.64  6.297600e+09  6.297600e+09
#
#         涨速  5分钟涨跌  60日涨跌幅  年初至今涨跌幅
# 5387  0.00   0.00   29.77    20.70
# ...

# %%
cleaned_data = df.drop_duplicates(subset='代码', keep='last')
cleaned_data.head()
# Out:
#    序号      代码    名称    最新价     涨跌幅    涨跌额       成交量          成交额     振幅  \
# 0   1  603120   N肯特  48.90  226.00  33.90  178495.0  922715936.0  77.33
# 1   2  301232  飞沃科技  28.24   20.02   4.71  117734.0  326164976.8  10.16
# 2   3  300605  恒锋信息  15.48   20.00   2.58  229878.0  342895284.5  21.40
# 3   4  300941  创识科技  24.18   20.00   4.03  203414.0  460898416.1  24.62
# 4   5  301618  长联科技  84.14   19.99  14.02   31468.0  250445232.0  18.51
#
#       最高  ...    量比    换手率  市盈率-动态   市净率           总市值          流通市值    涨速  \
# 0  60.06  ...   NaN  80.61   47.28  3.92  4.420560e+09  1.082833e+09  0.04
# 1  28.24  ...  9.40  26.36  -21.90  1.46  2.122585e+09  1.261404e+09  0.00
# 2  15.48  ...  3.16  19.33  -77.61  4.82  2.547634e+09  1.840949e+09  0.00
# 3  24.18  ...  3.68  16.77  131.21  3.92  4.950855e+09  2.932562e+09  0.00
# 4  84.14  ...  4.22  19.53   72.48  5.88  5.421973e+09  1.355495e+09  0.00
#
#    5分钟涨跌  60日涨跌幅  年初至今涨跌幅
# 0  -0.06  226.00   226.00
# 1   1.66   20.74    14.33
# ...

# %%
df.isnull().mean()
# Out:
# 序号         0.000000
# 代码         0.000000
# 名称         0.000000
# 最新价        0.055001
# 涨跌幅        0.055001
# 涨跌额        0.055001
# 成交量        0.055001
# 成交额        0.055001
# 振幅         0.055001
# 最高         0.055001
# 最低         0.055001
# 今开         0.055001
# 昨收         0.000175
# 量比         0.055176
# 换手率        0.000000
# 市盈率-动态     0.051498
# 市净率        0.051498
# 总市值        0.051498
# 流通市值       0.052023
# 涨速         0.055001
# 5分钟涨跌      0.055001
# 60日涨跌幅     0.000175
# 年初至今涨跌幅    0.000175
# dtype: float64
